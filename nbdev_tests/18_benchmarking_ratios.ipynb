# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import alphaquant.benchm.ratio_tests as aq_ratio_benchm

# Sample data for the DataFrame
data = {
    'protein': ['P1', 'P2', 'P3', 'P4'],
    'log2fc_alphaquant': [1.6, -1.6, 1.5, -1.3],
    'intensity_alphaquant': [10000, 15000, 8000, 12000],
    'organism': ['Mouse', 'Human', 'Mouse', 'Human'],
    'log2fc_spectronaut': [1.4, -1.8, 1.3, -1.5],
    'intensity_spectronaut': [9500, 14500, 8500, 11500]
}

# Create DataFrame
df_combined = pd.DataFrame(data)

# Define method suffixes and expected log2 fold changes
method_suffixes = ['_alphaquant', '_spectronaut']
expected_log2fcs = [1.5, -1.5]

# Instantiate MixedSpeciesFCPlotter with the test DataFrame
plotter = aq_ratio_benchm.MixedSpeciesFCPlotter(df_combined, method_suffixes, expected_log2fcs)

# Display the plot
plt.show()
