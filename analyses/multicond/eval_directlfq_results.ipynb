# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os

os.chdir('../../test_data/system_tests/multicond')

# %%
DIRECTLFQ_RESULT = "mouse_tissues_100prot_200ng_w_median.tsv.directlfq.protein_intensities.tsv"

# %%
import pandas as pd

df_directlfq = pd.read_csv(DIRECTLFQ_RESULT, sep='\t')
df_directlfq  = df_directlfq.set_index('protein')

display(df_directlfq)
# Out:
#                               20230926_OA2_CaWe_aQuant_mBrain_200ng_01.raw  \
# protein
# A0A0A0MQM0;P63242                                             3.904328e+07
# A0A0R4J1N9;P40630;P40630-2                                    7.072428e+06
# A0A0R4J2B2;Q6WVG3                                             8.814382e+05
# A0A1B0GRR3;P62281                                             5.242614e+06
# A0A1D5RLW5;A0A1D5RM85;P62717                                  1.580291e+06
# ...                                                                    ...
# Q9R062                                                        4.173015e+05
# Q9WTL7                                                        3.262808e+06
# Q9WUM5                                                        1.660274e+07
# Q9WVA2                                                        4.432858e+06
# Q9Z0N1                                                        3.976503e+06
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.clustermap(df_directlfq, method='average', metric='euclidean', cmap='viridis', figsize=(15, 10), z_score=0)

plt.show()
