# %%
import os
os.chdir('../../analyses_data/sensitivity_tests/phospho_peptides/')

# %%
INPUT_FILE = "20210309_173814_DIA_dilution_benchmark_nLClib_5PTMs_20190523_Report.tsv"
SAMPLEMAP = "samplemap.tsv"
RESULTS_DIR = "results"

# %%
import pandas as pd
df_input = pd.read_csv(INPUT_FILE, sep='\t')
# Out:
#                                      R.FileName PG.ProteinAccessions  \
# 0         20180815_QE3_nLC3_AH_DIA_Honly_ind_01        O14950;P19105
# 1         20180815_QE3_nLC3_AH_DIA_Honly_ind_01        O14950;P19105
# 2         20180815_QE3_nLC3_AH_DIA_Honly_ind_01        O14950;P19105
# 3         20180815_QE3_nLC3_AH_DIA_Honly_ind_01        O14950;P19105
# 4         20180815_QE3_nLC3_AH_DIA_Honly_ind_01        O14950;P19105
# ...                                         ...                  ...
# 11612068  20180816_QE3_nLC3_AH_DIA_H100_Y200_06               Q9Y6Y0
# 11612069  20180816_QE3_nLC3_AH_DIA_H100_Y200_06               Q9Y6Y0
# 11612070  20180816_QE3_nLC3_AH_DIA_H100_Y200_06               Q9Y6Y0
# 11612071  20180816_QE3_nLC3_AH_DIA_H100_Y200_06               Q9Y6Y0
# 11612072  20180816_QE3_nLC3_AH_DIA_H100_Y200_06               Q9Y6Y0
#
#           PG.Cscore     PG.Pvalue     PG.Qvalue  PG.RunEvidenceCount  \
# ...

# %%
display(df_input["R.FileName"].unique())
# Out:
# array(['20180815_QE3_nLC3_AH_DIA_Honly_ind_01',
#        '20180815_QE3_nLC3_AH_DIA_Honly_ind_02',
#        '20180815_QE3_nLC3_AH_DIA_Honly_ind_03',
#        '20180815_QE3_nLC3_AH_DIA_Yonly_ind_01',
#        '20180815_QE3_nLC3_AH_DIA_Yonly_ind_02',
#        '20180815_QE3_nLC3_AH_DIA_Yonly_ind_03',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y25_01',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y25_02',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y25_03',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y25_04',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y25_05',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y25_06',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y50_01',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y50_02',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y50_03',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y50_04',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y50_05',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y50_06',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y100_01',
#        '20180816_QE3_nLC3_AH_DIA_H100_Y100_02',
# ...

# %%
import alphaquant.run_pipeline as aq_run_pipeline

aq_run_pipeline.run_pipeline(input_file=INPUT_FILE, samplemap_file=SAMPLEMAP, results_dir=RESULTS_DIR)
# Out:
# 2024-03-18 16:37:25,313 - alphaquant.run_pipeline - INFO - Starting AlphaQuant
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import alphaquant.run_pipeline as aq_run_pipeline
# ----> 3 aq_run_pipeline.run_pipeline(input_file=INPUT_FILE, samplemap_file=SAMPLEMAP, results_dir=RESULTS_DIR)
#
# ...
