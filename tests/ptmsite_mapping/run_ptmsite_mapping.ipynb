# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import alphaquant.ptmsite_mapping as aqptm
import pandas as pd
import os

#data_dir = os.path.join("..", "..","test_data", "ptmsite_mapping")
data_dir = "../../test_data/unit_tests/ptmsite_mapping/"
results_dir = "../../test_data/unit_tests/ptmsite_mapping/results"

input_file = os.path.join(data_dir,"shortened_aq.tsv.zip")
samplemap = os.path.join(data_dir, "samplemap.tsv")
samplemap_df = pd.read_csv(samplemap, sep = "\t")

input_df = pd.read_csv(input_file, sep = "\t").drop_duplicates()
aqptm.assign_dataset(input_df, samplemap_df=samplemap_df, results_folder=results_dir)

#delete all files in results folder
for file in os.listdir(results_dir):
    os.remove(os.path.join(results_dir, file))
# Out:
# filtered PTM peptides from 352115 to 321137
# /Users/constantin/workspace/alphaquant/alphaquant/ptmsite_mapping.py:499: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_df["REFPROT"] = get_idmap_column(input_df[headers_dict.get("proteins")],swissprot_ids)
# /Users/constantin/workspace/alphaquant/alphaquant/ptmsite_mapping.py:500: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_df["IonID"] = input_df[label_column] + input_df[fg_id_column]
# ...
