# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os

os.chdir("../../../test_data/system_tests/proteoforms/mann_labs_egfr/")

# %%
input_file = "20230411_100022_20230330_Constantin_aQ2_Report.tsv.spectronaut_fragion_isotopes.aq_reformat.tsv"
ml_info_table = "20230803_163821_PhosphoLiDIA_Report.zip_ptmsite_mapped.tsv.ml_info_table.tsv"
#input_file = "../../test_data/system_tests/quicktests/100protein_set_spectronaut.tsv.spectronaut_fragion_isotopes.aq_reformat.tsv"
samplemap = "samplemap_egfr_100ng.tsv"
samplemap_200_center = "samplemap_200_center.tsv"
#samplemap = "../../test_data/system_tests/quicktests/samplemap.tsv"

input_file_phospho_original = "20230803_163821_PhosphoLiDIA_Report.tsv.zip"
input_file_phospho_ptmmapped = "20230803_163821_PhosphoLiDIA_Report.zip_ptmsite_mapped.tsv"
input_file_phospho = "20230803_163821_PhosphoLiDIA_Report.zip_ptmsite_mapped.tsv.spectronaut_ptm_fragion_isotopes.aq_reformat.tsv"
samplemap_phospho = "samplemap_phospho.tsv"

results_dir = "results"
results_dir_minrep5_fewclusterfilt = "results_minrep5_fewclusterfilt/"
results_dir_minrep5_median_ion = "results_minrep5_median_ion/"
results_dir_phospho = "results_phospho"

condpair_combinations=[('egf_treated', 'untreated')]

# %%
if True:
    import alphaquant.run_alphaquant as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir=results_dir, condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True)
# Out:
# removed pre existing /Users/constantin/workspace/alphaquant/test_data/system_tests/proteoforms/mann_labs_egfr/20230411_100022_20230330_Constantin_aQ2_Report.tsv.ml_info_table.tsv
# start processeing condpair ('egf_treated', 'untreated')
# normalized within conditions
# without missingvals (if applicable)
# complete dataset
# median 0.4235182011730636, mode 0.43893613795504705
# using median for shift
# shift comparison by -0.4235182011730636
# normalized between conditions
# t_ion2nonan_sw 1.3127810955047607
# t_intensity_selection 19.79934024810791
# t_ion2nonan_sw 1.1306228637695312
# t_intensity_selection 16.763076305389404
# checked 0 of 491131 ions
# checked 2000 of 491131 ions
# checked 4000 of 491131 ions
# checked 6000 of 491131 ions
# checked 8000 of 491131 ions
# checked 10000 of 491131 ions
# checked 12000 of 491131 ions
# checked 14000 of 491131 ions
# checked 16000 of 491131 ions
# checked 18000 of 491131 ions
# checked 20000 of 491131 ions
# ...

# %%
if True:
    import alphaquant.run_alphaquant as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap_200_center, results_dir="results_minrep15_clustp01_clustermerge03", condpair_combinations=condpair_combinations,
                         take_median_ion=False,minrep=15, runtime_plots=True,
                         cluster_threshold_pval=0.01,use_multiprocessing=False)
# Out:
# removed pre existing /Users/constantin/workspace/alphaquant/test_data/system_tests/proteoforms/mann_labs_egfr/20230411_100022_20230330_Constantin_aQ2_Report.tsv.ml_info_table.tsv
# start processeing condpair ('egf_treated', 'untreated')
# normalized within conditions
# without missingvals (if applicable)
# complete dataset
# median 0.8887118793294775, mode 0.8814358647077952
# using median for shift
# shift comparison by -0.8887118793294775
# normalized between conditions
# t_ion2nonan_sw 1.2134511470794678
# t_intensity_selection 43.06189203262329
# t_ion2nonan_sw 1.0756378173828125
# t_intensity_selection 37.922003984451294
# checked 0 of 441425 ions
# checked 2000 of 441425 ions
# checked 4000 of 441425 ions
# checked 6000 of 441425 ions
# checked 8000 of 441425 ions
# checked 10000 of 441425 ions
# checked 12000 of 441425 ions
# checked 14000 of 441425 ions
# checked 16000 of 441425 ions
# checked 18000 of 441425 ions
# checked 20000 of 441425 ions
# checked 22000 of 441425 ions
# ...

# %%
if True:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir="results_minrep5_clustp02_fcfc0_clustermerge05", condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval=0.2, cluster_threshold_fcfc=0, fcdiff_cutoff_clustermerge=0.5, ml_input_file = ml_info_table)
# Out:
# start processeing condpair ('egf_treated', 'untreated')
# normalized within conditions
# without missingvals (if applicable)
# complete dataset
# median 0.4235182011730636, mode 0.43893613795504705
# using median for shift
# shift comparison by -0.4235182011730636
# normalized between conditions
# t_ion2nonan_sw 1.195012092590332
# t_intensity_selection 19.216114044189453
# t_ion2nonan_sw 1.0340032577514648
# t_intensity_selection 16.859813928604126
# checked 0 of 491131 ions
# checked 2000 of 491131 ions
# checked 4000 of 491131 ions
# checked 6000 of 491131 ions
# checked 8000 of 491131 ions
# checked 10000 of 491131 ions
# checked 12000 of 491131 ions
# checked 14000 of 491131 ions
# checked 16000 of 491131 ions
# checked 18000 of 491131 ions
# checked 20000 of 491131 ions
# checked 22000 of 491131 ions
# checked 24000 of 491131 ions
# checked 26000 of 491131 ions
# checked 28000 of 491131 ions
# checked 30000 of 491131 ions
# checked 32000 of 491131 ions
# ...

# %%
if False:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir="results_minrep5_clustp02_fcfc0_clustermerge03", condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval=0.2, cluster_threshold_fcfc=0, fcdiff_cutoff_clustermerge=0.3)

# %%
if False:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir="results_minrep5_clustp02_fcfc0_clustermerge05_no_ml", condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval=0.2, cluster_threshold_fcfc=0, fcdiff_cutoff_clustermerge=0.5, use_ml=False)

# %%
if False:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir="results_minrep5_clustp02_fcfc0_clustermerge03_single_linkage", condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval=0.2, cluster_threshold_fcfc=0, fcdiff_cutoff_clustermerge=0.3, use_ml=True)

# %%
if True:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir="results_minrep5_clustp02_fcfc0_clustermerge07_single_linkage", condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval=0.2, cluster_threshold_fcfc=0, fcdiff_cutoff_clustermerge=0.7, use_ml=True)

# %%
if True:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir="results_minrep5_clustp02_fcfc0_clustermerge05_single_linkage", condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval=0.2, cluster_threshold_fcfc=0, fcdiff_cutoff_clustermerge=0.5, use_ml=True)

# %%
if True:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir=results_dir_minrep5_median_ion, condpair_combinations=condpair_combinations, 
                         take_median_ion=True,minrep=5, runtime_plots=True)

# %%
if True:
    import alphaquant.diff_analysis_manager as diffmgr
    diffmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap, results_dir=results_dir_minrep5_fewclusterfilt, condpair_combinations=condpair_combinations, take_median_ion=False,minrep=5, runtime_plots=True,
                         cluster_threshold_pval = 0.001, cluster_threshold_fcfc = 0.5)

# %%
if False:
	import alphaquant.diff_analysis_manager as diffmgr
	diffmgr.run_pipeline(input_file=input_file_phospho, samplemap_file=samplemap_phospho, results_dir=results_dir_phospho, condpair_combinations=condpair_combinations, take_median_ion=False,minrep=3, runtime_plots=True, modification_type="[Phospho (STY)]")

# %%
if False:
	import alphaquant.diff_analysis_manager as diffmgr
	diffmgr.run_pipeline(input_file=input_file_phospho, samplemap_file=samplemap_phospho, results_dir=results_dir_phospho, condpair_combinations=condpair_combinations, take_median_ion=False,minrep=3, runtime_plots=True)

# %%
if True:
	import alphaquant.diff_analysis_manager as diffmgr
	diffmgr.run_pipeline(input_file=input_file_phospho_original, samplemap_file=samplemap_phospho, results_dir="results_phospho_nocollapse", 
		      condpair_combinations=condpair_combinations, take_median_ion=True,minrep=3, runtime_plots=True, use_ml=False)
# Out:
# using input type spectronaut_fragion_isotopes
# start processeing condpair ('untreated', 'egf_treated')
# normalized within conditions
# without missingvals (if applicable)
# complete dataset
# median 0.1430852534070226, mode 0.14446766467580918
# using median for shift
# shift comparison by -0.1430852534070226
# normalized between conditions
# t_ion2nonan_sw 2.4827120304107666
# t_intensity_selection 25.22081708908081
# t_ion2nonan_sw 2.5021159648895264
# t_intensity_selection 26.223350048065186
# checked 0 of 920635 ions
# checked 2000 of 920635 ions
# checked 4000 of 920635 ions
# checked 6000 of 920635 ions
# checked 8000 of 920635 ions
# checked 10000 of 920635 ions
# checked 12000 of 920635 ions
# checked 14000 of 920635 ions
# checked 16000 of 920635 ions
# checked 18000 of 920635 ions
# checked 20000 of 920635 ions
# checked 22000 of 920635 ions
# checked 24000 of 920635 ions
# checked 26000 of 920635 ions
# checked 28000 of 920635 ions
# checked 30000 of 920635 ions
# ...
