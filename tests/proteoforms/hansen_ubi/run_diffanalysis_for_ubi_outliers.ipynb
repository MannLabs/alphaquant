# %%
#hide
# %reload_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("../../test_data/system_tests/ratio_tests/mann_labs_ubi/")

# %%
input_file = "20220505_203354_Full_Prot_DIA_cycling_hybrid____Report.tsv.spectronaut_fragion_isotopes.aq_reformat.tsv"
samplemap_file = "samplemap_proteome.tsv"
results_dir = "results_proteome"
ml_info_table_proteome = "proteome.RPAP2_SUBSET.ml_info_table.tsv"


input_file_ptm = "20220218_194556_DiGly_DIA_cycling____Report_ptmsite_mapped.tsv.spectronaut_ptm_fragion_isotopes.aq_reformat.tsv"
samplemap_file_ptm = "samplemap_ubi.tsv"
results_dir_ptm = "results_ubi"
ptm_name = "[GlyGly (K)]"


condpairs = [("t12", "t0")]

# %%
import alphaquant.diff_analysis_manager as aqmgr

aqmgr.run_pipeline(input_file=input_file_ptm, samplemap_file=samplemap_file_ptm, results_dir=results_dir_ptm,runtime_plots=True, minrep=None, use_ml=False,use_iontree_if_possible=True,condpair_combinations=condpairs)
# Out:
# start processeing condpair ('t12', 't0')
# normalized within conditions
# without missingvals (if applicable)
# complete dataset
# median -0.019462874526491092, mode -0.07537593303890144
# using mode for shift
# shift comparison by 0.07537593303890144
# normalized between conditions
# t_ion2nonan_sw 0.167741060256958
# t_intensity_selection 2.3747620582580566
# t_ion2nonan_sw 0.17853903770446777
# t_intensity_selection 2.541494131088257
# checked 0 of 77192 ions
# checked 2000 of 77192 ions
# checked 4000 of 77192 ions
# checked 6000 of 77192 ions
# checked 8000 of 77192 ions
# checked 10000 of 77192 ions
# checked 12000 of 77192 ions
# checked 14000 of 77192 ions
# checked 16000 of 77192 ions
# checked 18000 of 77192 ions
# checked 20000 of 77192 ions
# checked 22000 of 77192 ions
# checked 24000 of 77192 ions
# checked 26000 of 77192 ions
# checked 28000 of 77192 ions
# checked 30000 of 77192 ions
# checked 32000 of 77192 ions
# checked 34000 of 77192 ions
# ...

# %%
import alphaquant.diff_analysis_manager as aqmgr

aqmgr.run_pipeline(input_file=input_file, samplemap_file=samplemap_file, results_dir=results_dir,runtime_plots=True, minrep=None, condpair_combinations=condpairs, take_median_ion=False)
# Out:
# removed pre existing /Users/constantin/workspace/alphaquant/test_data/system_tests/ratio_tests/mann_labs_ubi/20220505_203354_Full_Prot_DIA_cycling_hybrid____Report.tsv.ml_info_table.tsv
# start processeing condpair ('t12', 't0')
# normalized within conditions
# without missingvals (if applicable)
# complete dataset
# median 0.4046661127761553, mode 0.4188970024666303
# using median for shift
# shift comparison by -0.4046661127761553
# normalized between conditions
# t_ion2nonan_sw 1.270442008972168
# t_intensity_selection 17.546801328659058
# t_ion2nonan_sw 1.2959260940551758
# t_intensity_selection 17.660297870635986
# checked 0 of 587022 ions
# checked 2000 of 587022 ions
# checked 4000 of 587022 ions
# checked 6000 of 587022 ions
# checked 8000 of 587022 ions
# checked 10000 of 587022 ions
# checked 12000 of 587022 ions
# checked 14000 of 587022 ions
# checked 16000 of 587022 ions
# checked 18000 of 587022 ions
# checked 20000 of 587022 ions
# checked 22000 of 587022 ions
# ...
