# %%
import yaml
import pandas as pd
import numpy as np
from matplotlib_venn import venn2
import matplotlib.pyplot as plt

def compare_generic_table_with_original(preprocessed_input_df, original_input_file, config_yaml,input_typename_config, sep = "\t"):
    id2quant_orig, id2quant_preproc = get_processed_original_id2quant_maps(preprocessed_input_df, original_input_file, config_yaml,input_typename_config)
    keys_orig = set(id2quant_orig.keys())
    keys_preproc = set(id2quant_preproc.keys())
    print(list(keys_orig)[:10])
    print(list(keys_preproc)[:10])
    
    
    assert(len(keys_preproc.difference(keys_orig))==0) #check that all keys in the preprocessed set are part of the original set

    venn2([set(id2quant_orig.keys()), set(id2quant_preproc.keys())], ["original", "preprocessed"])
    
    quantvec_orig = np.array([id2quant_orig.get(x)for x in id2quant_preproc.keys()])
    quantvec_preproc = np.array([id2quant_preproc.get(x)for x in id2quant_preproc.keys()])
    unequal_quant = [id2quant_orig.get(x)!=id2quant_preproc.get(x) for x in id2quant_preproc.keys()]
    unequal_quant_scaled = [id2quant_orig.get(x)*10000!=id2quant_preproc.get(x) for x in id2quant_preproc.keys()]
    print(sum(unequal_quant))
    print(sum(unequal_quant_scaled))
    plt.show()
    plt.scatter(quantvec_orig, quantvec_preproc)
    plt.show()
    corrcoeff = np.corrcoef(quantvec_orig,quantvec_preproc)[0][1]
    
    assert(corrcoeff>0.999)



def get_processed_original_id2quant_maps(preprocessed_input_df, original_input_file, config_yaml,input_typename_config, sep = "\t"):
    config_all = yaml.safe_load(open(config_yaml, 'r'))
    config_dict = config_all.get(input_typename_config)
    id_cols = config_dict.get("ion_cols") + [config_dict.get("sample_ID")]
    quant_col = config_dict.get("quant_ID")
    id2quant_orig = get_id2quant_original(original_input_file, id_cols, quant_col, sep)
    id2quant_preproc = get_id2quant_processed(preprocessed_input_df, id_cols, quant_col)
    return id2quant_orig, id2quant_preproc


def get_id2quant_original(original_input_file, id_cols, quant_col, sep):
    print(id_cols)
    print(id_cols+[quant_col])
    orig_df = pd.read_csv(original_input_file, sep=sep, usecols= id_cols+[quant_col])
    orig_df["compareID"] = orig_df[id_cols].astype('string').sum(axis = 1)
    display(orig_df)
    id2quant = dict(zip(orig_df["compareID"], orig_df[quant_col]))
    id2quant = {k: round(v,3) for k, v in id2quant.items()}
    return id2quant


def get_id2quant_processed(preprocessed_input_df, id_cols, quant_col):
    compare_IDs = []
    quantvals = []
    for column in preprocessed_input_df.columns:
        if(column == "protein"):
            continue
        ids = pd.Series([column for x in range(len(preprocessed_input_df.index))])
        compare_IDs.extend(list(preprocessed_input_df.index + ids))
        quantvals.extend(list(preprocessed_input_df[column]))
    
    id2quant = dict(zip(compare_IDs, quantvals))
    id2quant = {k: round(2**v,3) for k, v in id2quant.items() if ~np.isnan(v)}
    return id2quant


import alphaquant.diffquant_utils as aqutils
import os
tabledir = os.path.join("..", "..", "test_data", "input_table_formats")
results_folder = os.path.join(".", "results")
print(os.path.abspath(results_folder))


input_file = os.path.join(tabledir, "spectronaut.tsv")
samplemap_file = os.path.join(tabledir, "samplemap.spectronaut.tsv")


input_data = aqutils.import_data(input_file)
samplemap_df = aqutils.load_samplemap(samplemap_file)
input_processed, samplemap_df_processed = aqutils.prepare_loaded_tables(input_data, samplemap_df)
compare_generic_table_with_original(input_processed, input_file, os.path.join("..", "..", "intable_config.yaml"), "spectronaut_precursor_v2")

input_file = os.path.join(tabledir,"diann.tsv" )
samplemap_file = os.path.join(tabledir, "samplemap.diann.tsv")
input_data = aqutils.import_data(input_file)
samplemap_df = aqutils.load_samplemap(samplemap_file)
input_processed, samplemap_df_processed = aqutils.prepare_loaded_tables(input_data, samplemap_df)
compare_generic_table_with_original(input_processed, input_file, os.path.join("..", "..", "intable_config.yaml"), "diann_precursor")
# Out:
# /Users/constantin/workspace/alphaquant/tests/input_parsing/results
# recols	 ['Sequence', 'Reverse', 'Leading razor protein', 'Potential contaminant']
# recols	 ['Precursor.Quantity', 'Run', 'Precursor.Id', 'Quantity.Quality', 'Protein.Group']
# recols	 ['F.FrgIon', 'FG.Id', 'PEP.StrippedSequence', 'EG.ModifiedSequence', 'F.Charge', 'FG.MS1IsotopeIntensities (Measured)', 'PG.ProteinGroups', 'FG.Charge', 'R.Label', 'F.PeakArea', 'F.FrgLossType']
# recols	 ['FG.Quantity', 'R.Label', 'site_id', 'ion']
# recols	 ['FG.Id', 'EG.IsDecoy', 'FG.MS2RawQuantity', 'FG.ShapeQualityScore (MS2)', 'PG.ProteinGroups', 'R.Label']
# recols	 ['FG.Quantity', 'R.Label', 'FG.Id', 'PG.ProteinGroups']
# recols	 ['FG.Quantity', 'EG.ModifiedPeptide', 'PG.ProteinGroups', 'FG.Charge', 'R.Label']
# spectronaut_precursor_v2 headers in format longtable detected. Importing and re-formating.
# ['EG.ModifiedPeptide', 'FG.Charge', 'R.Label']
# ['EG.ModifiedPeptide', 'FG.Charge', 'R.Label', 'FG.Quantity']
#                                           R.Label  \
# 0     E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 1     E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 2     E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 3     E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 4     E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# ...                                           ...
# 9994  E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 9995  E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 9996  E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 9997  E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
# 9998  E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms
#
#                     EG.ModifiedPeptide  FG.Charge    FG.Quantity  \
# 0                        _LNVLPVDVLTR_          2   95427.601562
# 1                        _LNVLPVDVLTR_          2   95427.601562
# 2                        _LNVLPVDVLTR_          2   95427.601562
# 3                        _LNVLPVDVLTR_          2   95427.601562
# 4                        _LNVLPVDVLTR_          2   95427.601562
# ...                                ...        ...            ...
# 9994  _GC[Carbamidomethyl (C)]VITISGR_          2  110807.851562
# 9995  _GC[Carbamidomethyl (C)]VITISGR_          2  110807.851562
# 9996  _GC[Carbamidomethyl (C)]VITISGR_          2  110807.851562
# 9997  _GC[Carbamidomethyl (C)]VITISGR_          2  110807.851562
# 9998  _GC[Carbamidomethyl (C)]VITISGR_          2  110807.851562
#
#                                               compareID
# 0     _LNVLPVDVLTR_2E_D170331_S209-S-1-240min_MHRM_R...
# 1     _LNVLPVDVLTR_2E_D170331_S209-S-1-240min_MHRM_R...
# 2     _LNVLPVDVLTR_2E_D170331_S209-S-1-240min_MHRM_R...
# 3     _LNVLPVDVLTR_2E_D170331_S209-S-1-240min_MHRM_R...
# 4     _LNVLPVDVLTR_2E_D170331_S209-S-1-240min_MHRM_R...
# ...                                                 ...
# 9994  _GC[Carbamidomethyl (C)]VITISGR_2E_D170331_S20...
# 9995  _GC[Carbamidomethyl (C)]VITISGR_2E_D170331_S20...
# 9996  _GC[Carbamidomethyl (C)]VITISGR_2E_D170331_S20...
# 9997  _GC[Carbamidomethyl (C)]VITISGR_2E_D170331_S20...
# 9998  _GC[Carbamidomethyl (C)]VITISGR_2E_D170331_S20...
#
# [9999 rows x 5 columns]
# ['_EWVNLYHSAAAGR_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_IGGAYDSTK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_ILVATNLFGR_1E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_EIWLPPPQFYEVR_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_EDVIIAK_1E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_AAQLNIK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_TLVTLEQSR_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_MIGETNEYIK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_NLLVDSFK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_SLQDFLTVPK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms']
# ['_EWVNLYHSAAAGR_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_IGGAYDSTK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_ILVATNLFGR_1E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_EIWLPPPQFYEVR_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_EDVIIAK_1E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_AAQLNIK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_TLVTLEQSR_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_MIGETNEYIK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_NLLVDSFK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms', '_SLQDFLTVPK_2E_D170331_S209-S-1-240min_MHRM_R01_T0.htrms']
# 49
# 1716
# recols	 ['Sequence', 'Reverse', 'Leading razor protein', 'Potential contaminant']
# recols	 ['Precursor.Quantity', 'Run', 'Precursor.Id', 'Quantity.Quality', 'Protein.Group']
# diann_precursor headers in format longtable detected. Importing and re-formating.
# ['Precursor.Id', 'Run']
# ['Precursor.Id', 'Run', 'Precursor.Quantity']
#                                                     Run  \
# 0     20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 1     20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 2     20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 3     20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 4     20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# ...                                                 ...
# 9994  20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 9995  20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 9996  20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 9997  20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
# 9998  20210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast...
#
#                         Precursor.Id  Precursor.Quantity  \
# 0     AAAAAAAAAPAAAATAPTTAATTAATAAQ3             8180.60
# 1     AAAAAAAAAPAAAATAPTTAATTAATAAQ3            11270.20
# 2     AAAAAAAAAPAAAATAPTTAATTAATAAQ3            10255.00
# 3     AAAAAAAAAPAAAATAPTTAATTAATAAQ3            11853.30
# 4     AAAAAAAAAPAAAATAPTTAATTAATAAQ3             7742.75
# ...                              ...                 ...
# 9994       AC(UniMod:4)ADAGLLDESFLR2            13250.50
# 9995       AC(UniMod:4)ADAGLLDESFLR2            11063.90
# 9996       AC(UniMod:4)ADAGLLDESFLR2            10095.10
# 9997       AC(UniMod:4)ADAGLLDESFLR2             7817.40
# 9998       AC(UniMod:4)ADAGLLDESFLR2             9150.54
#
#                                               compareID
# 0     AAAAAAAAAPAAAATAPTTAATTAATAAQ320210407_tims03_...
# 1     AAAAAAAAAPAAAATAPTTAATTAATAAQ320210407_tims03_...
# 2     AAAAAAAAAPAAAATAPTTAATTAATAAQ320210407_tims03_...
# 3     AAAAAAAAAPAAAATAPTTAATTAATAAQ320210407_tims03_...
# 4     AAAAAAAAAPAAAATAPTTAATTAATAAQ320210407_tims03_...
# ...                                                 ...
# 9994  AC(UniMod:4)ADAGLLDESFLR220210407_tims03_Evo03...
# 9995  AC(UniMod:4)ADAGLLDESFLR220210407_tims03_Evo03...
# 9996  AC(UniMod:4)ADAGLLDESFLR220210407_tims03_Evo03...
# 9997  AC(UniMod:4)ADAGLLDESFLR220210407_tims03_Evo03...
# 9998  AC(UniMod:4)ADAGLLDESFLR220210407_tims03_Evo03...
#
# [9999 rows x 4 columns]
# ['AAAEVNQDYGLDPK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B4_1_24540', 'AAATAEEPDPK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B10_1_24558', 'AASAYAVGDVK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B10_1_24558', 'AAALEFLNRFEEAK320210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C1_1_24532', 'AAEFNSNLNR220210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C8_1_24553', 'AAGIDEQENWHEGK320210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C10_1_24559', 'AAAIGIDLGTTYSC(UniMod:4)VGVFQHGK320210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B3_1_24537', 'AALLEAGMPEC(UniMod:4)TEDK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_100ng_S2-A7_1_24548', 'AADSLQQNLQR220210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C5_1_24544', 'AAYWEEEPAEVR220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B12_1_24564']
# ['AASAYAVGDVK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B10_1_24558', 'AAATAEEPDPK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B10_1_24558', 'AAAEVNQDYGLDPK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B4_1_24540', 'AAALEFLNRFEEAK320210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C1_1_24532', 'AAEFNSNLNR220210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C8_1_24553', 'AAGIDEQENWHEGK320210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C10_1_24559', 'AALLEAGMPEC(UniMod:4)TEDK220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_100ng_S2-A7_1_24548', 'AAYWEEEPAEVR220210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B12_1_24564', 'AAAIGIDLGTTYSC(UniMod:4)VGVFQHGK320210407_tims03_Evo03_PaSk_SA_HeLa_100ng_Yeast_1ng_S2-B3_1_24537', 'AADSLQQNLQR220210407_tims03_Evo03_PaSk_SA_HeLa_200ng_Yeast_2ng_S2-C5_1_24544']
# 0
# 9972
